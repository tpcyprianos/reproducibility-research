# %% [markdown]
# # Working with Facebook Metrics
# This notebook will present the code to open and to load the dataset Facebook Metrics, and to display the data in a table.

# %% [markdown]
# ## Openning and Showing data using Panda Library

# %%
import pandas as pd

data = pd.read_csv('dataset_Facebook.csv', sep=";")
data[:500]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %% [markdown]
# ## Filtering and Ploting data

# %%
# %matplotlib inline
data[data["Type"] == "Link"]["Total Interactions"].plot()

# %%
data_filter = data["Type"] == "Link"
data_filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22      True
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 470     True
# 471    False
# 472    False
# 473    False
# 474    False
# 475    False
# 476    False
# 477     True
# 478    False
# 479    False
# 480    False
# 481     True
# 482    False
# 483    False
# 484    False
# 485     True
# 486    False
# 487    False
# 488    False
# 489    False
# 490    False
# 491    False
# 492     True
# 493    False
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Type, dtype: bool

# %%
filtered_data = data[data_filter]
filtered_data.head()
# Out:
#     Page total likes  Type  Category  Post Month  Post Weekday  Post Hour  \
# 22            138414  Link         1          12             7         10
# 41            138895  Link         1          12             6          3
# 43            138353  Link         1          12             5          3
# 45            138353  Link         1          12             4          3
# 47            138353  Link         1          12             3          2
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 22   0.0                       3454                             6853
# 41   1.0                      18480                            28438
# 43   1.0                       2645                             4270
# 45   1.0                       7968                            13023
# 47   0.0                       1925                             3481
#
#     Lifetime Engaged Users  Lifetime Post Consumers  \
# ...
